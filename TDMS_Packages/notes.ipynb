# %% [markdown]
# # NOTES FROM VS PROJECT

# %% [markdown]
# <b><font color="blue">DONE</font></b>
#
# - Need to implement struct-like objects in Python:
# 	- Feasible; follow the next link: https://stackoverflow.com/questions/35988/c-like-structures-in-python
# 		- Implement "dataclasses".
#
# <b><font color="red">TODO</font></b>
#
# - Need to know what the decorators do exactly.
# - Need to document the code properly.
# 	- The different function for the __init__ are not explained.
# 	- The philosophy or workflow does not seem correctly defined.
#
# <b><font color="green">ANNOTATIONS</font></b>
#
# - Flask --> Web development.
# - Kivy --> GUI development.
# - Hovercraft! --> Slides, presentations.
# - Type annotations and type checker.
# 	- Mypy --> Package for type-checking.
# 	- PEP 3107 (https://www.python.org/dev/peps/pep-3107/)
# 	- Smart introduction (https://www.youtube.com/watch?v=pMgmKJyWKn8)

# %% [markdown]
# # NOTES FROM SPYDER + JUPYTER PROJECT

# %% [markdown]
# <b><font color="blue">DONE</font></b>
#
# - Implement a virtual environment with __virtualenv__ and check whether spyeder is runnable from there. Currently, any package instalation done with __pip__ is mirrored by its __conda__ counterpart.
#
# <b><font color="red">TODO</font></b>
#
# <b><font color="green">ANNOTATIONS</font></b>
#
# - Check mpl3d for interactive matplotlib figures -> Is it worth it?
# - Check Jupyter + reveal.js for presentations -> Better than hovercraft?
# - Embed Python interpreter in a Python application (Kivy, Tkinter):
#     - https://stackoverflow.com/questions/21811464/how-can-i-embed-a-python-interpreter-frame-in-python-using-tkinter
# - Dynamic resize (zoom) of picture (image) in Jupyter Notebook.
#     - https://stackoverflow.com/questions/48335240/change-content-of-image-interactively-using-slider-widgets
# - Binder for sharing notebook online --> check on "python weekly": https://pythonweekly.us2.list-manage.com/track/click?u=e2e180baf855ac797ef407fc7&id=41026132d4&e=50c43cff59
