# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

import TDMS_Packages.TDMSClasses as TDMSC
import TDMS_Packages.TDMSEnums as TDMSE

list_of_files = []

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_bareAirfoil_Re1e5_AoA20/rawData_1.tdms",
                            "Kis_Bare_Re_100_e_3",
                            "Kistler, bare, $Re = 1{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.projected_means_only,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_bareAirfoil_Re1,5e5_AoA20/rawData_1.tdms",
                            "Kis_Bare_Re_150_e_3",
                            "Kistler, bare, $Re = 1.5{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.projected_means_only,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_bareAirfoil_Re0,75e5_AoA20/rawData_1.tdms",
                            "Kis_Bare_Re_75_e_3",
                            "Kistler, bare, $Re = 0.75{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.projected_means_only,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-20_NACA0021/wakeRake_angleWise_bareAirfoil_Re1e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Bare_Re_100_e_3_250_trailingEdge",
                            "Bare, $Re = 1{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.wake_rake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-20_NACA0021/wakeRake_angleWise_bareAirfoil_Re1,5e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Bare_Re_150_e_3_250_trailingEdge",
                            "Bare, $Re = 1.5{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.wake_rake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-20_NACA0021/wakeRake_angleWise_bareAirfoil_Re0,75e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Bare_Re_75_e_3_250_trailingEdge",
                            "Bare, $Re = 0.75{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.wake_rake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-09_NACA0021/Kistler_angleWise_triangularRoughness_double_sym_Re1e5_AoA20/rawData_0.tdms",
                            "Kis_Triangular_Double_Sym_Re_100_e_3",
                            "Kistler, triangular double symmetric, $Re = 1{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.projected_means_only,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-09_NACA0021/Kistler_angleWise_triangularRoughness_double_sym_Re1,5e5_AoA20/rawData_0.tdms",
                            "Kis_Triangular_Double_Sym_Re_150_e_3",
                            "Kistler, triangular double symmetric, $Re = 1.5{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.projected_means_only,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-09_NACA0021/Kistler_angleWise_triangularRoughness_double_sym_Re0,75e5_AoA20/rawData_0.tdms",
                            "Kis_Triangular_Double_Sym_Re_75_e_3",
                            "Kistler, triangular double symmetric, $Re = 0.75{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.projected_means_only,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-09_NACA0021/wakeRake_angleWise_triangularRoughness_double_sym_Re1e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Triangular_Double_Sym_Re_100_e_3_250_trailingEdge",
                            "Triangular double symmetric, $Re = 1{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.wake_rake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-09_NACA0021/wakeRake_angleWise_triangularRoughness_double_sym_Re1,5e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Triangular_Double_Sym_Re_150_e_3_250_trailingEdge",
                            "Triangular double symmetric, $Re = 1.5{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.wake_rake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-09_NACA0021/wakeRake_angleWise_triangularRoughness_double_sym_Re0,75e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_1.tdms",
                            "Triangular_Double_Sym_Re_75_e_3_250_trailingEdge",
                            "Triangular double symmetric, $Re = 0.75{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.wake_rake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))


TDMSC.open_list_of_files(list_of_files, reload=False)
# Out:
# Pickle file found: rawData_1.p. Loading data from serialized object.
# TDMS file 1 of 12 opened in projected_means_only mode; Kis_Bare_Re_100_e_3 global variable has been created.
# Pickle file found: rawData_1.p. Loading data from serialized object.
# TDMS file 2 of 12 opened in projected_means_only mode; Kis_Bare_Re_150_e_3 global variable has been created.
# Pickle file found: rawData_1.p. Loading data from serialized object.
# TDMS file 3 of 12 opened in projected_means_only mode; Kis_Bare_Re_75_e_3 global variable has been created.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 4 of 12 opened in wake_rake mode; Bare_Re_100_e_3_250_trailingEdge global variable has been created.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 5 of 12 opened in wake_rake mode; Bare_Re_150_e_3_250_trailingEdge global variable has been created.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# ...

# %%
plt.plot(Bare_Re_100_e_3_250_trailingEdge.groups_added.means_group.means_channels.angle_pos)
