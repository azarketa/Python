# %% [markdown]
# #  IMPORTING MODULES

# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 
import matplotlib.pyplot as plt
import numpy as np
import TDMS_Packages.python_TDMSClasses as TDMSC
import TDMS_Packages.python_TDMSEnums as TDMSE

# %% [markdown]
# # OPENING FILES
#
# ## The $\textit{list_of_files}$ variable stores all the instances of $\textit{TdmsFileData}$ objects which comprise the information of the data files to be loaded.
#
# ## The $\textit{open_list_of_files()}$ method loads the files.

# %%
list_of_files = list()

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-20_NACA0021/wakeRake_angleWise_bareAirfoil_Re1e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Bare_Re_100_e_3_250_trailingEdge",
                            "Bare, $Re = 1{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-20_NACA0021/wakeRake_angleWise_bareAirfoil_Re1,5e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Bare_Re_150_e_3_250_trailingEdge",
                            "Bare, $Re = 1.5{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-20_NACA0021/wakeRake_angleWise_bareAirfoil_Re0,75e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Bare_Re_75_e_3_250_trailingEdge",
                            "Bare, $Re = 0.75{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-21_NACA0021/wakeRake_angleWise_baseRoughness_Re1e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Circular_Re_100_e_3_250_trailingEdge",
                            "Circular, $Re = 1{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-21_NACA0021/wakeRake_angleWise_baseRoughness_Re1,5e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Circular_Re_150_e_3_250_trailingEdge",
                            "Circular, $Re = 1.5{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-21_NACA0021/wakeRake_angleWise_baseRoughness_Re0,75e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Circular_Re_75_e_3_250_trailingEdge",
                            "Circular, $Re = 0.75{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-25_NACA0021/wakeRake_angleWise_triangularRoughness_Re1e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_1.tdms",
                            "Triangular_Re_100_e_3_250_trailingEdge",
                            "Triangular, $Re = 1{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-25_NACA0021/wakeRake_angleWise_triangularRoughness_Re1,5e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_2.tdms",
                            "Triangular_Re_150_e_3_250_trailingEdge",
                            "Triangular, $Re = 1.5{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-25_NACA0021/wakeRake_angleWise_triangularRoughness_Re0,75e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Triangular_Re_75_e_3_250_trailingEdge",
                            "Triangular, $Re = 0.75{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-29_NACA0021/wakeRake_angleWise_triangularRoughness_Re1e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_0.tdms",
                            "Triangular_Re_100_e_3_250_trailingEdge_2",
                            "Triangular, $Re = 1{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-29_NACA0021/wakeRake_angleWise_triangularRoughness_Re1,5e5_staticReference_2,5fromTrailingEdge_AoA20/rawData_1.tdms",
                            "Triangular_Re_150_e_3_250_trailingEdge_2",
                            "Triangular, $Re = 1.5{\\cdot}10^{5}$, $250\\%C$ from trailing edge",
                            TDMSE.tdmsFilereadMode.WakeRake,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_bareAirfoil_Re1e5_AoA20/rawData_1.tdms",
                            "Kis_Bare_Re_100_e_3",
                            "Kistler, bare, $Re = 1{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_bareAirfoil_Re1,5e5_AoA20/rawData_1.tdms",
                            "Kis_Bare_Re_150_e_3",
                            "Kistler, bare, $Re = 1.5{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_bareAirfoil_Re0,75e5_AoA20/rawData_1.tdms",
                            "Kis_Bare_Re_75_e_3",
                            "Kistler, bare, $Re = 0.75{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_baseRoughness_Re1e5_AoA20/rawData_1.tdms",
                            "Kis_Circular_Re_100_e_3",
                            "Kistler, circular, $Re = 1{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_baseRoughness_Re1,5e5_AoA20/rawData_0.tdms",
                            "Kis_Circular_Re_150_e_3",
                            "Kistler, circular, $Re = 1.5{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_baseRoughness_Re0,75e5_AoA20/rawData_0.tdms",
                            "Kis_Circular_Re_75_e_3",
                            "Kistler, circular, $Re = 0.75{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_triangularRoughness_Re1e5_AoA20/rawData_0.tdms",
                            "Kis_Triangular_Re_100_e_3",
                            "Kistler, triangular, $Re = 1{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_triangularRoughness_Re1,5e5_AoA20/rawData_0.tdms",
                            "Kis_Triangular_Re_150_e_3",
                            "Kistler, triangular, $Re = 1.5{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))
list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-03-22_NACA0021/Kistler_angleWise_triangularRoughness_Re0,75e5_AoA20/rawData_1.tdms",
                            "Kis_Triangular_Re_75_e_3",
                            "Kistler, triangular, $Re = 0.75{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

list_of_files.append(TDMSC.TdmsFileData("C:/Dropbox (MGEP)/INTERNAL/Project_Doc/THESIS/Tests/NACA0021/2019-04-02_NACA0021/Kistler_angleWise_largeRoughness_Re1e5_AoA20/rawData_0.tdms",
                            "Kis_Large_Re_100_e_3",
                            "Kistler, large, $Re = 1{\\cdot}10^{5}$",
                            TDMSE.tdmsFilereadMode.ProjectedMeansOnly,
                            TDMSC.RefMagnitudes(length = 0.15, span = 0.9, thick = 0.15*0.21)
                            ))

TDMSC.open_list_of_files(list_of_files, globals())
# Out:
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 1 of 21 opened in WakeRake mode; stored in Bare_Re_100_e_3_250_trailingEdge global variable.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 2 of 21 opened in WakeRake mode; stored in Bare_Re_150_e_3_250_trailingEdge global variable.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 3 of 21 opened in WakeRake mode; stored in Bare_Re_75_e_3_250_trailingEdge global variable.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 4 of 21 opened in WakeRake mode; stored in Circular_Re_100_e_3_250_trailingEdge global variable.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# TDMS file 5 of 21 opened in WakeRake mode; stored in Circular_Re_150_e_3_250_trailingEdge global variable.
# Pickle file found: rawData_0.p. Loading data from serialized object.
# ...

# %%
# Uncomment this line for inline plots.
# %matplotlib inline
#Uncomment this line for windowed plots.
# %matplotlib qt5

# %%
for file in [Kis_Bare_Re_100_e_3, Kis_Circular_Re_100_e_3, Kis_Triangular_Re_100_e_3, Kis_Large_Re_100_e_3]:
    angles, lift = zip(*sorted(zip(file.groups_added.means_group.means_channels.Angle_pos, 
                                  file.groups_added.means_group.means_channels.lift)))
    plt.plot(angles, lift, marker = 'o')
    
plt.grid()
plt.xlabel('$AoA, ^{\circ}$', fontsize = 20)
plt.ylabel('$C_{L}$', fontsize = 20)
# Out:
# Text(0, 0.5, '$C_{L}$')
